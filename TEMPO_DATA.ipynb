# %%
import os
from getpass import getpass
from netrc import netrc
from platform import system
from subprocess import Popen

# %%
urs = "urs.earthdata.nasa.gov"  # Earthdata URL endpoint for authentication
prompts = ["Enter NASA Earthdata Login Username: ", "Enter NASA Earthdata Login Password: "]

# Determine the OS (Windows machines usually use an '_netrc' file)
netrc_name = "_netrc" if system() == "Windows" else ".netrc"

# Determine if netrc file exists, and if so, if it includes NASA Earthdata Login Credentials
try:
    netrcDir = os.path.expanduser(f"~/{netrc_name}")
    netrc(netrcDir).authenticators(urs)[0]

# Below, create a netrc file and prompt user for NASA Earthdata Login Username and Password
except FileNotFoundError:
    homeDir = os.path.expanduser("~")
    Popen(
        "touch {0}{2} | echo machine {1} >> {0}{2}".format(homeDir + os.sep, urs, netrc_name),
        shell=True,
    )
    Popen(
        "echo login {} >> {}{}".format(getpass(prompt=prompts[0]), homeDir + os.sep, netrc_name),
        shell=True,
    )
    Popen(
        "echo 'password {} '>> {}{}".format(
            getpass(prompt=prompts[1]), homeDir + os.sep, netrc_name
        ),
        shell=True,
    )
    # Set restrictive permissions
    Popen("chmod 0600 {0}{1}".format(homeDir + os.sep, netrc_name), shell=True)

    # Determine OS and edit netrc file if it exists but is not set up for NASA Earthdata Login
except TypeError:
    homeDir = os.path.expanduser("~")
    Popen("echo machine {1} >> {0}{2}".format(homeDir + os.sep, urs, netrc_name), shell=True)
    Popen(
        "echo login {} >> {}{}".format(getpass(prompt=prompts[0]), homeDir + os.sep, netrc_name),
        shell=True,
    )
    Popen(
        "echo 'password {} '>> {}{}".format(
            getpass(prompt=prompts[1]), homeDir + os.sep, netrc_name
        ),
        shell=True,
    )

# %%
import boto3
import requests
import xarray as xr

# %matplotlib inline

# %%
s3_cred_endpoint = "https://data.asdc.earthdata.nasa.gov/s3credentials"

# %%
def get_temp_creds():
    temp_creds_url = s3_cred_endpoint
    return requests.get(temp_creds_url).json()

# %%
temp_creds_req = get_temp_creds()

# %%
s3_client = boto3.client(
    "s3",
    aws_access_key_id=temp_creds_req["accessKeyId"],
    aws_secret_access_key=temp_creds_req["secretAccessKey"],
    aws_session_token=temp_creds_req["sessionToken"],
)

# %%
bucket = "asdc-prod-protected"
local_dir = "./no2"
os.makedirs(local_dir, exist_ok=True)

# %%
# cell 2:  read the list you saved earlier
with open("AWS_NO2.txt") as f:
    s3_urls = [line.strip() for line in f if line.strip()]

# %%
# cell 3:  loop and download
count = 1
for s3_url in s3_urls:
    key = s3_url.replace("s3://asdc-prod-protected/", "")
    file_name = key.split("/")[-1]
    local_path = os.path.join(local_dir, file_name)

    if os.path.exists(local_path):
        print("skip ", file_name)
        continue

    print(count,"-","downloading", file_name)
    s3_client.download_file(
        bucket,
        key,
        local_path,
        ExtraArgs={"RequestPayer": "requester"}
    )
    count+=1
# Out:
# 1 - downloading TEMPO_NO2_L3_V03_20250131T230228Z_S013.nc
# 2 - downloading TEMPO_NO2_L3_V03_20250131T222220Z_S012.nc
# 3 - downloading TEMPO_NO2_L3_V03_20250131T212220Z_S011.nc
# 4 - downloading TEMPO_NO2_L3_V03_20250131T202220Z_S010.nc
# 5 - downloading TEMPO_NO2_L3_V03_20250131T192220Z_S009.nc
# 6 - downloading TEMPO_NO2_L3_V03_20250131T182220Z_S008.nc
# 7 - downloading TEMPO_NO2_L3_V03_20250131T172220Z_S007.nc
# 8 - downloading TEMPO_NO2_L3_V03_20250131T162220Z_S006.nc
# 9 - downloading TEMPO_NO2_L3_V03_20250131T152220Z_S005.nc
# 10 - downloading TEMPO_NO2_L3_V03_20250131T142220Z_S004.nc
# 11 - downloading TEMPO_NO2_L3_V03_20250131T134212Z_S003.nc
# 12 - downloading TEMPO_NO2_L3_V03_20250131T130204Z_S002.nc
# 13 - downloading TEMPO_NO2_L3_V03_20250130T230218Z_S013.nc
# 14 - downloading TEMPO_NO2_L3_V03_20250130T222210Z_S012.nc
# 15 - downloading TEMPO_NO2_L3_V03_20250130T212210Z_S011.nc
# 16 - downloading TEMPO_NO2_L3_V03_20250130T202210Z_S010.nc
# 17 - downloading TEMPO_NO2_L3_V03_20250130T192210Z_S009.nc
# 18 - downloading TEMPO_NO2_L3_V03_20250130T182210Z_S008.nc
# 19 - downloading TEMPO_NO2_L3_V03_20250130T172210Z_S007.nc
# 20 - downloading TEMPO_NO2_L3_V03_20250130T162210Z_S006.nc
# 21 - downloading TEMPO_NO2_L3_V03_20250130T152210Z_S005.nc
# 22 - downloading TEMPO_NO2_L3_V03_20250130T142210Z_S004.nc
# 23 - downloading TEMPO_NO2_L3_V03_20250130T134202Z_S003.nc
# 24 - downloading TEMPO_NO2_L3_V03_20250130T130154Z_S002.nc
# 25 - downloading TEMPO_NO2_L3_V03_20250129T230209Z_S013.nc
# 26 - downloading TEMPO_NO2_L3_V03_20250129T222201Z_S012.nc
# 27 - downloading TEMPO_NO2_L3_V03_20250129T212201Z_S011.nc
# 28 - downloading TEMPO_NO2_L3_V03_20250129T202201Z_S010.nc
# 29 - downloading TEMPO_NO2_L3_V03_20250129T192201Z_S009.nc
# 30 - downloading TEMPO_NO2_L3_V03_20250129T182201Z_S008.nc
# 31 - downloading TEMPO_NO2_L3_V03_20250129T172201Z_S007.nc
# 32 - downloading TEMPO_NO2_L3_V03_20250129T162201Z_S006.nc
# 33 - downloading TEMPO_NO2_L3_V03_20250129T152201Z_S005.nc
# 34 - downloading TEMPO_NO2_L3_V03_20250129T142201Z_S004.nc
# 35 - downloading TEMPO_NO2_L3_V03_20250129T134153Z_S003.nc
# 36 - downloading TEMPO_NO2_L3_V03_20250129T130145Z_S002.nc
# 37 - downloading TEMPO_NO2_L3_V03_20250128T212151Z_S011.nc
# 38 - downloading TEMPO_NO2_L3_V03_20250128T202150Z_S010.nc
# 39 - downloading TEMPO_NO2_L3_V03_20250128T192150Z_S009.nc
# 40 - downloading TEMPO_NO2_L3_V03_20250128T182150Z_S008.nc
# 41 - downloading TEMPO_NO2_L3_V03_20250128T172150Z_S007.nc
# 42 - downloading TEMPO_NO2_L3_V03_20250128T162150Z_S006.nc
# 43 - downloading TEMPO_NO2_L3_V03_20250128T152150Z_S005.nc
# 44 - downloading TEMPO_NO2_L3_V03_20250128T142150Z_S004.nc
# 45 - downloading TEMPO_NO2_L3_V03_20250128T134142Z_S003.nc
# 46 - downloading TEMPO_NO2_L3_V03_20250128T130134Z_S002.nc
# 47 - downloading TEMPO_NO2_L3_V03_20250127T230146Z_S013.nc
# 48 - downloading TEMPO_NO2_L3_V03_20250127T222138Z_S012.nc
# 49 - downloading TEMPO_NO2_L3_V03_20250127T212138Z_S011.nc
# 50 - downloading TEMPO_NO2_L3_V03_20250127T202138Z_S010.nc
# 51 - downloading TEMPO_NO2_L3_V03_20250127T192138Z_S009.nc
# 52 - downloading TEMPO_NO2_L3_V03_20250127T182138Z_S008.nc
# 53 - downloading TEMPO_NO2_L3_V03_20250127T172138Z_S007.nc
# 54 - downloading TEMPO_NO2_L3_V03_20250127T162138Z_S006.nc
# 55 - downloading TEMPO_NO2_L3_V03_20250127T152138Z_S005.nc
# 56 - downloading TEMPO_NO2_L3_V03_20250127T142138Z_S004.nc
# 57 - downloading TEMPO_NO2_L3_V03_20250127T134130Z_S003.nc
# 58 - downloading TEMPO_NO2_L3_V03_20250127T130122Z_S002.nc
# 59 - downloading TEMPO_NO2_L3_V03_20250126T230134Z_S013.nc
# 60 - downloading TEMPO_NO2_L3_V03_20250126T222126Z_S012.nc
# 61 - downloading TEMPO_NO2_L3_V03_20250126T212126Z_S011.nc
# 62 - downloading TEMPO_NO2_L3_V03_20250126T202126Z_S010.nc
# 63 - downloading TEMPO_NO2_L3_V03_20250126T192126Z_S009.nc
# 64 - downloading TEMPO_NO2_L3_V03_20250126T182126Z_S008.nc
# 65 - downloading TEMPO_NO2_L3_V03_20250126T172126Z_S007.nc
# 66 - downloading TEMPO_NO2_L3_V03_20250126T162126Z_S006.nc
# 67 - downloading TEMPO_NO2_L3_V03_20250126T152126Z_S005.nc
# 68 - downloading TEMPO_NO2_L3_V03_20250126T142126Z_S004.nc
# 69 - downloading TEMPO_NO2_L3_V03_20250126T134118Z_S003.nc
# 70 - downloading TEMPO_NO2_L3_V03_20250126T130110Z_S002.nc
# 71 - downloading TEMPO_NO2_L3_V03_20250125T230120Z_S012.nc
# 72 - downloading TEMPO_NO2_L3_V03_20250125T222112Z_S011.nc
# 73 - downloading TEMPO_NO2_L3_V03_20250125T212112Z_S010.nc
# 74 - downloading TEMPO_NO2_L3_V03_20250125T202112Z_S009.nc
# 75 - downloading TEMPO_NO2_L3_V03_20250125T192112Z_S008.nc
# 76 - downloading TEMPO_NO2_L3_V03_20250125T182112Z_S007.nc
# 77 - downloading TEMPO_NO2_L3_V03_20250125T172112Z_S006.nc
# 78 - downloading TEMPO_NO2_L3_V03_20250125T171215Z_S005.nc
# 79 - downloading TEMPO_NO2_L3_V03_20250125T142113Z_S004.nc
# 80 - downloading TEMPO_NO2_L3_V03_20250125T134104Z_S003.nc
# 81 - downloading TEMPO_NO2_L3_V03_20250125T130056Z_S002.nc
# 82 - downloading TEMPO_NO2_L3_V03_20250124T230106Z_S013.nc
# 83 - downloading TEMPO_NO2_L3_V03_20250124T222058Z_S012.nc
# 84 - downloading TEMPO_NO2_L3_V03_20250124T212058Z_S011.nc
# 85 - downloading TEMPO_NO2_L3_V03_20250124T202058Z_S010.nc
# 86 - downloading TEMPO_NO2_L3_V03_20250124T192058Z_S009.nc
# 87 - downloading TEMPO_NO2_L3_V03_20250124T182058Z_S008.nc
# 88 - downloading TEMPO_NO2_L3_V03_20250124T172058Z_S007.nc
# 89 - downloading TEMPO_NO2_L3_V03_20250124T162058Z_S006.nc
# 90 - downloading TEMPO_NO2_L3_V03_20250124T152058Z_S005.nc
# 91 - downloading TEMPO_NO2_L3_V03_20250124T142058Z_S004.nc
# 92 - downloading TEMPO_NO2_L3_V03_20250124T134050Z_S003.nc
# 93 - downloading TEMPO_NO2_L3_V03_20250124T130042Z_S002.nc
# 94 - downloading TEMPO_NO2_L3_V03_20250123T230051Z_S013.nc
# 95 - downloading TEMPO_NO2_L3_V03_20250123T222043Z_S012.nc
# 96 - downloading TEMPO_NO2_L3_V03_20250123T212043Z_S011.nc
# 97 - downloading TEMPO_NO2_L3_V03_20250123T202043Z_S010.nc
# 98 - downloading TEMPO_NO2_L3_V03_20250123T192043Z_S009.nc
# 99 - downloading TEMPO_NO2_L3_V03_20250123T182043Z_S008.nc
# 100 - downloading TEMPO_NO2_L3_V03_20250123T172043Z_S007.nc

# %%
import xarray as xr

# %%
df = xr.open_dataset("/content/no2/TEMPO_NO2_L3_V03_20250123T172043Z_S007.nc")
df.dims
# Out:
# FrozenMappingWarningOnValuesAccess({'latitude': 2950, 'longitude': 7750, 'time': 1})

# %%
import xarray as xr, pandas as pd, glob, os, numpy as np ,tqdm
from datetime import datetime

# %%
folder = "/content/no2"               # wherever you downloaded
files  = sorted(glob.glob(os.path.join(folder, "*.nc")))
epoch = pd.Timestamp('1980-01-06')
print(f"{len(files)} files found")
# Out:
# 100 files found

# %%
def one_file_to_hourly(path):
    """return 24-row dataframe (hour, mean trop, mean strat, mean flag)"""
    # 1. real scan time
    with xr.open_dataset(path) as root:
        dt = epoch + pd.Timedelta(seconds=float(root.time)/1e9)
    date = dt.date()

    # 2. open product group
    with xr.open_dataset(path, group='product') as prod:
        trop  = prod.vertical_column_troposphere.squeeze()
        strat = prod.vertical_column_stratosphere.squeeze()
        flag  = prod.main_data_quality_flag.squeeze()

    # 3. spatial mean per hour (already 1 file = 1 hour)
    hour = dt.hour
    return pd.DataFrame({
        'date': date,
        'hour': hour,
        'latitude_centre': trop.latitude.mean().item(),
        'longitude_centre': trop.longitude.mean().item(),
        'vertical_column_troposphere': trop.mean().item(),
        'vertical_column_stratosphere': strat.mean().item(),
        'main_data_quality_flag': flag.mean().item()
    }, index=[0])

# 4. collect all
df_all = []
for f in tqdm.tqdm(files, desc='nc → 24-row'):
    df_all.append(one_file_to_hourly(f))

# 5. pivot to 24 rows per calendar day
big = pd.concat(df_all, ignore_index=True)
big = big.sort_values(['date','hour'])
big.to_csv('TEMPO_NO2_24hour_perDay.csv', index=False)
print("done → TEMPO_NO2_24hour_perDay.csv")
# Out:
# nc → 24-row: 100%|██████████| 100/100 [04:36<00:00,  2.77s/it]
# done → TEMPO_NO2_24hour_perDay.csv

# %%
# open ONLY the science_data group, keep the two column densities
ds = xr.open_mfdataset(
        files,
        group='product',          # <-- key line
        combine='nested',
        concat_dim='time',
        chunks={'time': 100}
     )
[['vertical_column_troposphere', 'vertical_column_stratosphere','main_data_quality_flag','time','latitude','longitude']]
# Out:
# [['vertical_column_troposphere',
#   'vertical_column_stratosphere',
#   'main_data_quality_flag',
#   'time',
#   'latitude',
#   'longitude']]

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 100)> Size: 800B
# [100 values with dtype=int64]
# Dimensions without coordinates: time

# %%
# TEMPO files carry a scalar ‘time’ – turn it into a coordinate
ds = ds.assign_coords(time=pd.to_datetime(ds.time))

# %%
hourly = ds.groupby('time.hour').mean('time')   # or .sum(), .first(), etc.
# if you prefer a true datetime index instead of ‘hour’ 0…23:
# hourly = ds.resample(time='1H').mean()

# %%
print("original time coord:", ds.time.dtype, ds.time.shape)
print("sample times:", ds.time.isel(time=slice(0,3)).values)
# Out:
# original time coord: datetime64[ns] (100,)
# sample times: ['1970-01-01T00:00:00.000000000' '1970-01-01T00:00:00.000000001'
#  '1970-01-01T00:00:00.000000002']
